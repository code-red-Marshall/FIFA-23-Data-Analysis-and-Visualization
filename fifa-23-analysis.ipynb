# %%
#Data Analysis on FIFA 23 Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('/kaggle/input/fifa-23-players-dataset/Fifa 23 Players Data.csv')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data.head(10)
# Out:
#             Known As                     Full Name  Overall  Potential  \
# 0           L. Messi                  Lionel Messi       91         91
# 1         K. Benzema                 Karim Benzema       91         91
# 2     R. Lewandowski            Robert Lewandowski       91         91
# 3       K. De Bruyne               Kevin De Bruyne       91         91
# 4          K. Mbappé                 Kylian Mbappé       91         95
# 5           M. Salah                 Mohamed Salah       90         90
# 6        T. Courtois              Thibaut Courtois       90         91
# 7           M. Neuer                  Manuel Neuer       90         90
# 8  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90         90
# 9        V. van Dijk               Virgil van Dijk       90         90
#
#    Value(in Euro) Positions Played Best Position  Nationality  \
# 0        54000000               RW           CAM    Argentina
# ...

# %% [markdown]
# # Exploring the data

# %% [markdown]
# # How to remove spaces from column names and save them back in the dataframe*

# %%
data_columns = data.columns.str.replace(" ","_")

# %%
data_columns
# Out:
# Index(['Known_As', 'Full_Name', 'Overall', 'Potential', 'Value(in_Euro)',
#        'Positions_Played', 'Best_Position', 'Nationality', 'Image_Link', 'Age',
#        'Height(in_cm)', 'Weight(in_kg)', 'TotalStats', 'BaseStats',
#        'Club_Name', 'Wage(in_Euro)', 'Release_Clause', 'Club_Position',
#        'Contract_Until', 'Club_Jersey_Number', 'Joined_On', 'On_Loan',
#        'Preferred_Foot', 'Weak_Foot_Rating', 'Skill_Moves',
#        'International_Reputation', 'National_Team_Name',
#        'National_Team_Image_Link', 'National_Team_Position',
#        'National_Team_Jersey_Number', 'Attacking_Work_Rate',
#        'Defensive_Work_Rate', 'Pace_Total', 'Shooting_Total', 'Passing_Total',
#        'Dribbling_Total', 'Defending_Total', 'Physicality_Total', 'Crossing',
#        'Finishing', 'Heading_Accuracy', 'Short_Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick_Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
data.columns = data_columns

# %%
data.columns
# Out:
# Index(['Known_As', 'Full_Name', 'Overall', 'Potential', 'Value(in_Euro)',
#        'Positions_Played', 'Best_Position', 'Nationality', 'Image_Link', 'Age',
#        'Height(in_cm)', 'Weight(in_kg)', 'TotalStats', 'BaseStats',
#        'Club_Name', 'Wage(in_Euro)', 'Release_Clause', 'Club_Position',
#        'Contract_Until', 'Club_Jersey_Number', 'Joined_On', 'On_Loan',
#        'Preferred_Foot', 'Weak_Foot_Rating', 'Skill_Moves',
#        'International_Reputation', 'National_Team_Name',
#        'National_Team_Image_Link', 'National_Team_Position',
#        'National_Team_Jersey_Number', 'Attacking_Work_Rate',
#        'Defensive_Work_Rate', 'Pace_Total', 'Shooting_Total', 'Passing_Total',
#        'Dribbling_Total', 'Defending_Total', 'Physicality_Total', 'Crossing',
#        'Finishing', 'Heading_Accuracy', 'Short_Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick_Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
data
# Out:
#              Known_As           Full_Name  Overall  Potential  Value(in_Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %% [markdown]
# # Highest Potential Possessing player

# %%
data[data["Potential"]==data["Potential"].max()]
# Out:
#     Known_As      Full_Name  Overall  Potential  Value(in_Euro)  \
# 4  K. Mbappé  Kylian Mbappé       91         95       190500000
#
#   Positions_Played Best_Position Nationality  \
# 4            ST,LW            ST      France
#
#                                          Image_Link  Age  ...  LM_Rating  \
# 4  https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
#
#    CM_Rating  RM_Rating  LWB_Rating CDM_Rating  RWB_Rating  LB_Rating  \
# 4         84         92          70         66          70         66
#
#   CB_Rating RB_Rating GK_Rating
# 4        57        66        21
#
# [1 rows x 89 columns]

# %% [markdown]
# # Overall Highest Rated Player

# %%
data[data["Overall"]==data["Overall"].max()]
# Out:
#          Known_As           Full_Name  Overall  Potential  Value(in_Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions_Played Best_Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image_Link  Age  ...  LM_Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %%
data[(data["Overall"]==data["Overall"].max()) & (data.Preferred_Foot=="Left")]
# Out:
#    Known_As     Full_Name  Overall  Potential  Value(in_Euro)  \
# 0  L. Messi  Lionel Messi       91         91        54000000
#
#   Positions_Played Best_Position Nationality  \
# 0               RW           CAM   Argentina
#
#                                          Image_Link  Age  ...  LM_Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
#
#    CM_Rating  RM_Rating  LWB_Rating CDM_Rating  RWB_Rating  LB_Rating  \
# 0         88         91          67         66          67         62
#
#   CB_Rating RB_Rating GK_Rating
# 0        53        62        22
#
# [1 rows x 89 columns]

# %%
data[(data["Overall"]==data["Overall"].max()) & (data.Preferred_Foot=="Right")]
# Out:
#          Known_As           Full_Name  Overall  Potential  Value(in_Euro)  \
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions_Played Best_Position Nationality  \
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image_Link  Age  ...  LM_Rating  \
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# 2  https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3  https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data= pd.DataFrame(data)
data
# Out:
#              Known_As           Full_Name  Overall  Potential  Value(in_Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
# ...

# %%
data.dtypes.unique()
# Out:
# array([dtype('O'), dtype('int64')], dtype=object)

# %%
data.dtypes
# Out:
# Known_As          object
# Full_Name         object
# Overall            int64
# Potential          int64
# Value(in_Euro)     int64
#                    ...
# RWB_Rating         int64
# LB_Rating          int64
# CB_Rating          int64
# RB_Rating          int64
# GK_Rating          int64
# Length: 89, dtype: object

# %% [markdown]
# # Describing DataFrame and some information related to it

# %% [markdown]
# **data.describe()** is a method in Pandas that provides a summary of descriptive statistics for numerical columns in a DataFrame. It's a quick way to get an overview of the central tendency, spread, and distribution of your data. Let's break down the output of data.describe():
# When you call data.describe() on a DataFrame named data, it generates statistics for each numeric column in the DataFrame. The output consists of several common statistical measures:
#
# **Count**: The count row shows how many non-null values are present in each column. This tells you how many data points are available for analysis in each column.
#
# **Mean (Average)**: The mean row displays the average value of each column. It gives you an idea of the central tendency of the data.
#
# **Standard Deviation**:The standard deviation row measures the dispersion or spread of values around the mean. A higher standard deviation indicates more variability in the data.
#
# **Minimum and Maximum**: The minimum and maximum rows show the smallest and largest values in each column, respectively. They help you understand the range of values present in the data.
#
# **25th, 50th (Median), and 75th Percentiles**: The percentile rows provide information about the distribution of data. For instance, the 25th percentile represents the value below which 25% of the data falls, the 50th percentile is the median (middle value), and the 75th percentile is the value below which 75% of the data falls.

# %%
data.describe()
# Out:
#             Overall     Potential  Value(in_Euro)           Age  \
# count  18539.000000  18539.000000    1.853900e+04  18539.000000
# mean      65.852042     71.016668    2.875461e+06     25.240412
# std        6.788353      6.192866    7.635129e+06      4.718163
# min       47.000000     48.000000    0.000000e+00     16.000000
# 25%       62.000000     67.000000    4.750000e+05     21.000000
# 50%       66.000000     71.000000    1.000000e+06     25.000000
# 75%       70.000000     75.000000    2.000000e+06     29.000000
# max       91.000000     95.000000    1.905000e+08     44.000000
#
#        Height(in_cm)  Weight(in_kg)    TotalStats     BaseStats  \
# count   18539.000000   18539.000000  18539.000000  18539.000000
# mean      181.550839      75.173904   1602.114569    357.946221
# std         6.858097       7.013593    273.160237     39.628259
# min       155.000000      49.000000    759.000000    224.000000
# 25%       177.000000      70.000000   1470.000000    331.000000
# ...

# %%
data["Age"].describe()
# Out:
# count    18539.000000
# mean        25.240412
# std          4.718163
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         29.000000
# max         44.000000
# Name: Age, dtype: float64

# %% [markdown]
# # Count
# The concept of "count" is quite simple. In the context of data and statistics, "count" refers to the number of things you have.
#
# For example, imagine you have a group of friends and you're counting the number of people who like a certain type of food. If you find out that 10 friends like pizza, then the count of people who like pizza is 10.
#
# In data analysis, "count" is used to tell you how many times something occurs in a dataset. This "something" could be anything you're interested in, like the number of times a certain word appears in a text, the number of people in a certain age group, or the number of times a specific event happened.
#
# For instance, if you're looking at the ages of people in a survey and you see that there are 20 people aged 25, then the count of people aged 25 is 20.

# %%
data["Age"].describe()
# Out:
# count    18539.000000
# mean        25.240412
# std          4.718163
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         29.000000
# max         44.000000
# Name: Age, dtype: float64

# %% [markdown]
# # Central tendency
#
# Its a way to describe where the "center" or "typical" value of a set of numbers is. Imagine you have a bunch of numbers, like the scores of your friends on a test. Central tendency helps you answer questions like:
#
# "What's the average score?"
# "Where is the middle score?"
# "Are the scores mostly higher or lower?"
#
# Mean (Average):
#
# This is what you get when you add up all the scores and divide by how many scores there are. It gives you an idea of what most of your friends scored on average.
# Median (Middle Value):
#
# Imagine you lined up all your friends' scores from lowest to highest. The median is the score right in the middle. It's the value that separates the lower half of scores from the higher half.
# Mode (Most Common Value):
#
# If one score shows up more often than any other, that's the mode. It's like saying, "This is the score most people got."
# Each of these measures tells you something about where the data tends to cluster. For example, if most of your friends got similar scores, the mean, median, and mode might be close together. But if there are a few really high scores, the mean might be higher than the median because those high scores pull the average up.
#
# Central tendency helps you understand what's typical or "central" in a group of numbers. Just remember that it's not the whole story; it's just one way to describe a bunch of data!

# %%
data["Value(in_Euro)"].describe()
# Out:
# count    1.853900e+04
# mean     2.875461e+06
# std      7.635129e+06
# min      0.000000e+00
# 25%      4.750000e+05
# 50%      1.000000e+06
# 75%      2.000000e+06
# max      1.905000e+08
# Name: Value(in_Euro), dtype: float64

# %% [markdown]
# # 25th, 50th and 75th percentiles:
#
# Percentiles help you understand where a specific value falls within a set of data. They're like signposts along a road that show you how far you've traveled compared to others. Let's break down the 25th, 50th (median), and 75th percentiles with an example:
#
# Imagine you're at a gathering with your friends and you're all sharing your scores from a video game. Here's what those percentiles might mean:
#
# 25th Percentile:
#
# This is like saying, "Hey, you're doing better than 25% of your friends!" If your score is at the 25th percentile, it means that 25% of your friends have scores lower than yours and 75% have scores higher than yours.
# 50th Percentile (Median):
#
# The median is the middle value in your friend group's scores. If your score is the median, it means half of your friends have scores lower than yours, and half have scores higher.
# 75th Percentile:
#
# This is like saying, "Wow, you're outperforming 75% of your friends!" If your score is at the 75th percentile, it means that 75% of your friends have scores lower than yours and only 25% have scores higher.
# Here's a simple example to help you visualize:
#
# Imagine your friends' scores in the video game are: 10, 15, 20, 25, 30.
#
# The 25th percentile score is the one below which 25% of your friends' scores fall. Since 25% of 5 friends is about 1.25 friends, you'd look at the second score, which is 15.
# The median (50th percentile) is the middle score, which is 20.
# The 75th percentile score is the one below which 75% of your friends' scores fall. Since 75% of 5 friends is about 3.75 friends, you'd look at the fourth score, which is 25.

# %%
data.groupby('Age').describe()
# Out:
#     Overall                                                      Potential  \
#       count       mean       std   min    25%   50%    75%   max     count
# Age
# 16     31.0  54.548387  4.113706  48.0  51.50  54.0  57.00  64.0      31.0
# 17    249.0  56.381526  4.880324  47.0  53.00  55.0  60.00  79.0     249.0
# 18    626.0  58.070288  5.029975  47.0  54.00  58.0  62.00  75.0     626.0
# 19   1039.0  59.842156  5.676755  47.0  56.00  60.0  63.00  85.0    1039.0
# 20   1260.0  61.227778  5.617093  48.0  58.00  61.0  65.00  82.0    1260.0
# 21   1440.0  62.642361  6.081038  47.0  59.00  63.0  66.00  88.0    1440.0
# 22   1602.0  64.563046  6.363158  48.0  61.00  64.0  68.00  85.0    1602.0
# 23   1356.0  65.665192  6.151950  48.0  62.00  65.0  69.00  91.0    1356.0
# 24   1333.0  66.839460  6.090018  48.0  63.00  66.0  70.00  86.0    1333.0
# 25   1372.0  67.408892  6.015153  47.0  64.00  67.0  71.00  88.0    1372.0
# ...

# %% [markdown]
# # Groupby()
# The groupby() function in Pandas is like a magical organizer for your data. It helps you group and organize your data based on a particular column's values. Imagine you have a lot of data about people, and you want to organize them by their countries. Here's how groupby() works:
#
# Split:
#
# First, you "split" your data into smaller groups based on the values in a chosen column. So, if you're using countries as the basis, you'll end up with separate groups for each country.
# Apply:
#
# Once you have these groups, you can "apply" operations to them. This means you can do calculations, like finding the average age for each country's group, or counting how many people are from each country.
# Combine:
#
# Finally, after applying the operations, you "combine" the results. This is where you get a neat summary of your data, organized by the values you used for grouping.
# Let's break it down with an example:
#
# Imagine you have a dataset about people with columns like "Name," "Country," and "Age." You want to know the average age of people in each country.
#
# The groupby() function grouped the data by the "Country" column and then calculated the average age for each country's group. The resulting summary tells you the average age of people from Canada and the USA.
#
# So, groupby() is a powerful tool that helps you organize, analyze, and summarize your data based on specific categories or values in a column.

# %%
data.groupby('Age').describe().unstack()
# Out:
#                   Age
# Overall    count  16       31.0
#                   17      249.0
#                   18      626.0
#                   19     1039.0
#                   20     1260.0
#                           ...
# GK_Rating  max    39       79.0
#                   40       79.0
#                   41       71.0
#                   42       72.0
#                   44       79.0
# Length: 15680, dtype: float64

# %%
data.groupby(["Age", "Overall"])["Value(in_Euro)"].sum().unstack()
# Out:
# Overall        47         48         49         50         51         52  \
# Age
# 16            NaN   130000.0   220000.0   420000.0   310000.0   480000.0
# 17       190000.0        NaN   380000.0  1750000.0  2330000.0  4260000.0
# 18       130000.0        NaN   930000.0  1940000.0  3400000.0  6450000.0
# 19       110000.0  1090000.0   970000.0  1690000.0  2680000.0  5890000.0
# 20            NaN   960000.0   670000.0  1890000.0  1670000.0  4660000.0
# 21       110000.0   340000.0  1070000.0  1160000.0  2680000.0  3800000.0
# 22            NaN   700000.0   250000.0  1180000.0  1170000.0  2430000.0
# 23            NaN   170000.0   350000.0   490000.0   330000.0   930000.0
# 24            NaN   140000.0        NaN   120000.0   380000.0   730000.0
# 25        60000.0    60000.0        NaN   170000.0   150000.0   500000.0
# 26            NaN        NaN        NaN   110000.0   140000.0   290000.0
# 27            NaN        NaN        NaN    95000.0        NaN   160000.0
# ...

# %% [markdown]
# # Info()
# The data.info() method in Pandas provides a concise summary of a DataFrame's structure and contents. It gives you important information about the data types, non-null values, memory usage, and more. This is very helpful for quickly getting an overview of your dataset. Here's what each part of the output means:
#
# Non-null Count: This column shows how many non-null (not missing) values are present in each column. It's a quick way to see if there are any missing values in your dataset.
#
# Data Type: This column displays the data type of each column. Data types include integers, floats, strings, etc. Understanding the data types is important for data analysis and operations.
#
# Memory Usage: This line provides an estimate of the memory used by the DataFrame. It can be helpful to monitor memory consumption, especially when working with large datasets.
#
# The data.info() output is an essential starting point when you're exploring a new dataset or preparing it for analysis. It helps you understand how the data is structured and identify potential data quality issues (like missing values) that might need to be addressed before proceeding with your analysis.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known_As                     18539 non-null  object
#  1   Full_Name                    18539 non-null  object
#  2   Overall                      18539 non-null  int64
#  3   Potential                    18539 non-null  int64
#  4   Value(in_Euro)               18539 non-null  int64
#  5   Positions_Played             18539 non-null  object
#  6   Best_Position                18539 non-null  object
#  7   Nationality                  18539 non-null  object
#  8   Image_Link                   18539 non-null  object
#  9   Age                          18539 non-null  int64
#  10  Height(in_cm)                18539 non-null  int64
#  11  Weight(in_kg)                18539 non-null  int64
#  12  TotalStats                   18539 non-null  int64
# ...

# %% [markdown]
# # How to count the number of rows using index and len
#
# The expression len(Data.index) is used to determine the number of rows (entries) in a DataFrame called Data. It returns the total count of rows present in the DataFrame. Here's what it means:
#
# Data: This is the name of the DataFrame you're working with. You would replace this with the actual name of your DataFrame.
#
# len(): This is a built-in Python function that calculates the length (number of items) of a given object. When you pass in Data.index to len(), you're essentially asking Python to calculate the length of the index of the DataFrame.
#
# Data.index: This refers to the index of the DataFrame, which represents the labels or identifiers for the rows in the DataFrame. By using Data.index, you're accessing the index of the DataFrame.
#
# So, when you put it all together, len(Data.index) calculates the length of the index of the DataFrame Data, which is equivalent to the number of rows in that DataFrame. It's a simple and straightforward way to count the number of rows in a Pandas DataFrame.

# %%
len(data.index)
# Out:
# 18539

# %% [markdown]
# # **VISUALIZATION STARTS FROM HERE**

# %% [markdown]
# # Top 10 valued players based on salaries

# %%
# Find the player with the maximum value
max_value_player = data.loc[data['Value(in_Euro)'].idxmax()]
max_value_player
max_value_index = data['Value(in_Euro)'].idxmax()
player_name = data.loc[max_value_index, 'Full_Name']
player_value = data.loc[max_value_index, 'Value(in_Euro)']
print("Player with the maximum value:\nName: {}\nValue in Euro: {}".format(player_name, player_value))
# Out:
# Player with the maximum value:
# Name: Kylian Mbappé
# Value in Euro: 190500000

# %%
df_sorted = data.sort_values('Value(in_Euro)', ascending=False)
df_sorted
player_name = df_sorted.iloc[:10]['Full_Name']
player_value = df_sorted.iloc[:10]['Value(in_Euro)']

# %% [markdown]
#  Here the code is creating a horizontal bar chart using the plt.barh() function from Matplotlib.

# %%
plt.figure(figsize=(10, 6))
plt.barh(player_name, player_value)
plt.xlabel('Value')
plt.ylabel('Player')
plt.title('Player with the Maximum Value')
plt.show()

# %% [markdown]
# # Scatter Plot for Age vs Value

# %% [markdown]
# A scatter plot is a type of graphical representation used to display the relationship between two variables or data sets. It uses individual data points as dots on a two-dimensional plane, with one variable plotted on the x-axis and the other variable plotted on the y-axis. Each dot on the scatter plot represents a single observation in your data.
#
# Here's how to understand a scatter plot:
#
# X-Axis and Y-Axis:
#
# The horizontal axis is called the x-axis, and it represents one variable.
# The vertical axis is called the y-axis, and it represents the other variable.
# Data Points (Dots):
#
# Each data point is represented by a dot on the plot, located at the intersection of its x and y values.
# The position of each dot shows how the two variables are related for that specific observation.
# Patterns and Relationships:
#
# Scatter plots are used to reveal patterns, trends, or relationships between two variables.
# If the dots cluster or follow a general direction, it suggests a correlation or trend between the variables.
# Outliers:
#
# Outliers, which are data points that deviate significantly from the overall pattern, can also be identified on scatter plots.
# Axes Labels and Title:
#
# The axes are labeled to provide context and understanding of what the variables represent.
# The plot usually has a title that describes what the scatter plot is showing.
# For example, if you're plotting age against height for a group of people, the scatter plot will show how height varies with age. If the dots trend upward as age increases, it suggests a positive correlation between age and height. If there's no clear trend, it indicates that there might not be a strong relationship between the two variables.
#
# Scatter plots are valuable tools for visualizing data and exploring relationships between variables in a quick and intuitive way.

# %%
plt.figure(figsize=(12, 6))
plt.scatter(data['Age'], data['Value(in_Euro)'])
plt.scatter(df_sorted.iloc[:10]['Age'], df_sorted.iloc[:10]['Value(in_Euro)'], color='red', label='Player with Max Value')
plt.xlabel('Age')
plt.ylabel('Value(in Euro)')
plt.title('Player Value vs. Age')
plt.legend()
plt.show()

# %% [markdown]
# # Insight:
# From the above scatter plot, its clear that young players are more prone to high payment. Especially between the age 20 to 25.

# %%
Portugese_players= data[data["Nationality"]=="Portugal"]
Portugese_players
# Out:
#                 Known_As                       Full_Name  Overall  Potential  \
# 8      Cristiano Ronaldo    C. Ronaldo dos Santos Aveiro       90         90
# 20            Rúben Dias    Rúben Santos Gato Alves Dias       88         91
# 23        Bernardo Silva  Bernardo Mota Carvalho e Silva       88         88
# 24          João Cancelo       João Pedro Cavaco Cancelo       88         88
# 53       Bruno Fernandes   Bruno Miguel Borges Fernandes       86         86
# ...                  ...                             ...      ...        ...
# 16364       Filipe Sissé                    Filipe Sissé       58         68
# 16398     Rafael Moreira      Rafael Mascarenhas Moreira       58         66
# 16537     Gabriel Castro        Gabriel Fernandes Castro       57         68
# 17670        K. Costinha                  Kevin Costinha       54         63
# 17719     Diogo Monteiro         Diogo Pinheiro Monteiro       54         78
#
# ...

# %%
Portugese_players.loc[Portugese_players['Overall'].idxmax()].head(5)
# Out:
# Known_As                     Cristiano Ronaldo
# Full_Name         C. Ronaldo dos Santos Aveiro
# Overall                                     90
# Potential                                   90
# Value(in_Euro)                        41000000
# Name: 8, dtype: object

# %%
sns.set_palette("Set1")
plt.figure(figsize=(12, 6))
plt.ylabel("Performance")
sns.lineplot(x='Weight(in_kg)', y='Acceleration', data=data, label="Pace", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Shot_Power', data=data, label="Shooting", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Skill_Moves', data=data, label="Swiftness", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Heading_Accuracy', data=data, label="Aerial", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Interceptions', data=data, label="Aggression", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='BallControl', data=data, label="Control", legend='brief')
# Out:
# <Axes: xlabel='Weight(in_kg)', ylabel='Performance'>

# %% [markdown]
# # Line Plot using Seaborn

# %% [markdown]
# A line plot, also known as a line chart or line graph, is a visualization that displays data points connected by straight lines. It is commonly used to show the trend or progression of a variable over a continuous range, such as time, age, or any other ordered sequence. Seaborn is a Python data visualization library that can be used to create line plots easily and effectively.
#
# Here's how to understand a line plot created using Seaborn:
#
# Data Points and Lines:
#
# Data points are represented by markers (usually dots) along the plot's horizontal axis.
# Lines connect these markers, creating a continuous line that shows the overall trend.
# X-Axis and Y-Axis:
#
# The x-axis typically represents the independent variable, which is usually a continuous value such as time.
# The y-axis represents the dependent variable, which can be any numerical value you want to visualize.
# Trends and Patterns:
#
# Line plots are especially useful for revealing trends, patterns, or changes in the dependent variable over the range of the independent variable.
# Upward or downward trends in the line indicate changes in the variable being plotted.
# Multiple Lines and Legends:
#
# You can create line plots with multiple lines on the same plot, which allows for easy comparison between different variables or conditions.
# Legends help identify which line corresponds to which variable or condition.

# %%
# Set the color palette
sns.set_palette("Set1")

# Create a larger figure
plt.figure(figsize=(12, 6))  # Adjust the width and height as needed

# Create the line plots
sns.lineplot(x='Weight(in_kg)', y='Acceleration', data=data, label="Accelaration", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Shot_Power', data=data, label="Shot Power", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Skill_Moves', data=data, label="Skills", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Heading_Accuracy', data=data, label="Heading", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='Interceptions', data=data, label="Interceptions", legend='brief')
sns.lineplot(x='Weight(in_kg)', y='BallControl', data=data, label="Ball Control", legend='brief')

# Set the y-axis label
plt.ylabel("Performance")

# Display the plot
plt.show()

# %%
# Set the color palette
sns.set_palette("Set2")

# Create a larger figure
plt.figure(figsize=(12, 6))  # Adjust the width and height as needed

# Create the line plots
sns.lineplot(x='Age', y='Stamina', data=data, label="Stamina", legend='brief')
sns.lineplot(x='Age', y='Dribbling', data=data, label="Dribbling", legend='brief')
sns.lineplot(x='Age', y='Physicality_Total', data=data, label="Physicality", legend='brief')
sns.lineplot(x='Age', y='Aggression', data=data, label="Aggression", legend='brief')
sns.lineplot(x='Age', y='Sprint_Speed', data=data, label="Sprint_Speed", legend='brief')
sns.lineplot(x='Age', y='Composure', data=data, label="Composure", legend='brief')

# Set the y-axis label
plt.ylabel("Performance")

# Display the plot
plt.show()

# %%
gk= data[data.Best_Position=="GK"]
gk[0:10]
topgks=gk.sort_values(by=["Potential"],ascending= False)
topgks
# Out:
#             Known_As                  Full_Name  Overall  Potential  \
# 22     G. Donnarumma       Gianluigi Donnarumma       88         92
# 6        T. Courtois           Thibaut Courtois       90         91
# 14          J. Oblak                  Jan Oblak       89         91
# 16           Ederson  Ederson Santana de Moraes       89         91
# 7           M. Neuer               Manuel Neuer       90         90
# ...              ...                        ...      ...        ...
# 18376        A. Paul               Avilash Paul       50         53
# 18068       K. Singh             Karanjit Singh       52         52
# 18198       L. Ralte        Lalthuammawia Ralte       52         52
# 18052       P. Kumar                Pawan Kumar       52         52
# 18245         Wu Fei                     Fei Wu       51         51
#
#        Value(in_Euro) Positions_Played Best_Position Nationality  \
# 22          103500000               GK            GK       Italy
# ...

# %%
# Set the color palette
sns.set_palette("Set1")

# Create a larger figure
plt.figure(figsize=(12, 6))  # Adjust the width and height as needed

# Create the line plots
sns.lineplot(x='Age', y='Goalkeeper_Diving', data=gk, label="Goalkeeper_Diving", legend='brief')
sns.lineplot(x='Age', y='Goalkeeper_Handling', data=gk, label="Goalkeeper_Handling", legend='brief')
sns.lineplot(x='Age', y='_GoalkeeperKicking', data=gk, label="GoalkeeperKicking", legend='brief')
sns.lineplot(x='Age', y='Goalkeeper_Positioning', data=gk, label="Goalkeeper_Positioning", legend='brief')
sns.lineplot(x='Age', y='Goalkeeper_Reflexes', data=gk, label="Goalkeeper_Reflexes", legend='brief')
#sns.lineplot(x='Age', y='Value(in_Euro)', data=topgks, label="LongPassing", legend='brief')

# Set the y-axis label
plt.ylabel("Performance")

# Display the plot
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# 1. As per the weight measures in the dataset compared to other factors such as Accelaration, Shot Power, Skills, Heading Ability and other such quality features, we have come to conclusion that the suitable weight for a player to perform on top should be in between 55-70 kgs.
#
# 2. As per the analysis based on Age with other enduring factors, I'd recommend players between the age of 23-28

# %% [markdown]
# # Countplot using Seaborn
#
# The Seaborn library is used to create a count plot for the 'Age' column in a DataFrame named data. Let's break down the code step by step:
#
# Setting Figure Size:
#
# **sns.set(rc={'figure.figsize': (20, 10)})**: This line sets the figure size for the plot. It adjusts the dimensions of the plot's visual area. In this case, the width is set to 20 units, and the height is set to 10 units.
# Creating the Count Plot:
#
# **ax = sns.countplot(x='Age', data=data, width=0.4)**: This line creates a count plot using Seaborn's countplot() function. It specifies that the 'Age' column from the DataFrame data will be plotted on the x-axis. The width parameter controls the width of the bars in the count plot. The ax variable is used to capture the axes of the plot, which allows you to customize and add labels to the bars later.
# Adding Bar Labels:
#
# **for bars in ax.containers**: This loop iterates through the containers (bars) in the count plot.
# ax.bar_label(bars): This line adds labels to the bars in the count plot. It displays the count of each category on top of its respective bar.

# %%
# plotting a bar chart for Age and it's count
sns.set(rc={'figure.figsize':(20,10)})
ax = sns.countplot(x = 'Age',data = data ,width=0.3)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Height and it's count
sns.set(rc={'figure.figsize':(20,10)})
ax = sns.countplot(x = 'Height(in_cm)',data = data ,width=0.4)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for Weight and it's count
sns.set(rc={'figure.figsize':(20,10)})
ax = sns.countplot(x = 'Weight(in_kg)',data = data ,width=0.4)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Value.counts()
#
#  The value_counts() function is like a tally for your data. It helps you count how many times each unique value appears in a column of your dataset.
#
# Imagine you have a list of favorite colors from a group of friends. Some like red, some like blue, and so on. When you use value_counts():
#
# It looks at your list of colors.
# It counts how many times each color appears.
# Then, it gives you a summary that shows the count for each color.

# %%
# Count the number of players in each position
position_counts = data['Positions_Played'].value_counts()
position_counts
# Out:
# CB            2433
# GK            2061
# ST            1719
# CDM,CM         953
# CM             732
#               ...
# LM,CF,ST         1
# CAM,CM,LWB       1
# LB,LM,RB         1
# CM,RW,CDM        1
# CM,CF,CDM        1
# Name: Positions_Played, Length: 693, dtype: int64

# %%
# Group players based on the number of positions they can play
grouped_players = position_counts.value_counts()
grouped_players
# Out:
# 1       224
# 2       102
# 3        54
# 5        30
# 4        29
#        ...
# 99        1
# 100       1
# 30        1
# 103       1
# 2433      1
# Name: Positions_Played, Length: 87, dtype: int64

# %% [markdown]
# # Pie Chart

# %% [markdown]
# Here, we are filtering the **position_counts** variable to only include positions where the count is greater than 478. This means you're focusing on the most common positions, presumably the top 8 positions in terms of frequency.
# **filtered_position_counts['Others'] = position_counts[position_counts <= 478].sum()**
#
# This line adds an 'Others' category to the filtered_position_counts variable. It counts the total number of positions with counts less than or equal to 478 and assigns that count to the 'Others' category. This is a common technique used to group less frequent categories into a single category for simplicity in visualizations.
#
# plt.figure(figsize=(10, 10)): This line sets the figure size for the plot.
#
# plt.pie(): This function creates a pie chart. It takes the values (counts) and labels from filtered_position_counts and displays them as a pie chart. The autopct parameter formats the percentage labels on the chart.
#
# plt.title(): This adds a title to the pie chart.
#
# plt.show(): This line displays the pie chart.

# %%
import matplotlib.pyplot as plt
# Filter First 8 positions
filtered_position_counts = position_counts[position_counts > 450]

# Combine positions with count <= 5 into 'Others' category
filtered_position_counts['Others'] = position_counts[position_counts <= 450].sum()

plt.figure(figsize=(10, 10))
plt.pie(filtered_position_counts.values, labels=filtered_position_counts.index, autopct='%1.1f%%')
plt.title('Proportion of First 8 positions')
plt.show()

# %%
data.columns
# Out:
# Index(['Known_As', 'Full_Name', 'Overall', 'Potential', 'Value(in_Euro)',
#        'Positions_Played', 'Best_Position', 'Nationality', 'Image_Link', 'Age',
#        'Height(in_cm)', 'Weight(in_kg)', 'TotalStats', 'BaseStats',
#        'Club_Name', 'Wage(in_Euro)', 'Release_Clause', 'Club_Position',
#        'Contract_Until', 'Club_Jersey_Number', 'Joined_On', 'On_Loan',
#        'Preferred_Foot', 'Weak_Foot_Rating', 'Skill_Moves',
#        'International_Reputation', 'National_Team_Name',
#        'National_Team_Image_Link', 'National_Team_Position',
#        'National_Team_Jersey_Number', 'Attacking_Work_Rate',
#        'Defensive_Work_Rate', 'Pace_Total', 'Shooting_Total', 'Passing_Total',
#        'Dribbling_Total', 'Defending_Total', 'Physicality_Total', 'Crossing',
#        'Finishing', 'Heading_Accuracy', 'Short_Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick_Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
nationality_counts= data["Nationality"].value_counts()
nationality_counts
# Out:
# England          1632
# Germany          1204
# Spain            1074
# France            963
# Argentina         937
#                  ...
# Bermuda             1
# Kazakhstan          1
# Liechtenstein       1
# Korea DPR           1
# Barbados            1
# Name: Nationality, Length: 160, dtype: int64

# %%
# Filter Most 20 Nationalists
filtered_nationality_counts = nationality_counts[nationality_counts > 300]

# Combine Nationalists with count <= 5 into 'Others' category
filtered_nationality_counts['Others'] = nationality_counts[nationality_counts <= 300].sum()

plt.figure(figsize=(10, 10))
plt.pie(filtered_nationality_counts.values, labels=filtered_nationality_counts.index, autopct='%1.1f%%')
plt.title('Proportion of Players Most 20 Nationalists ')
plt.show()

# %%
filtered_nationality_counts
# Out:
# England                1632
# Germany                1204
# Spain                  1074
# France                  963
# Argentina               937
# Brazil                  728
# Italy                   623
# China PR                439
# United States           437
# Netherlands             428
# Poland                  390
# Sweden                  390
# Republic of Ireland     385
# Portugal                382
# Norway                  373
# Romania                 341
# Saudi Arabia            331
# Korea Republic          319
# Denmark                 318
# Belgium                 318
# Others                 6527
# Name: Nationality, dtype: int64

# %% [markdown]
# # Sorting players by their overall value

# %%
# Sort the dataset by value in descending order
df_sorted = data.sort_values('Overall', ascending=False)

# Get the first players with the maximum value
player_name = df_sorted.iloc[:10]['Full_Name']
player_value = df_sorted.iloc[:10]['Overall']

# Create a horizontal bar chart
plt.figure(figsize=(25, 6))
plt.bar(player_name, player_value)
plt.xlabel('Overall')
plt.ylabel('Player')
plt.title('Player with the Maximum Overall ')
plt.show()

# %% [markdown]
# # Making a Pie Chart based on preferred foot

# %%
preferred_foot_count = data["Preferred_Foot"].value_counts()
preferred_foot_count
# Out:
# Right    14045
# Left      4494
# Name: Preferred_Foot, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.pie(preferred_foot_count.values, labels=preferred_foot_count.index, autopct='%1.1f%%')
plt.title('Proportion of preferred foot')
plt.show()

# %% [markdown]
# # Bar plot of the First Player in each position with the maximum value

# %%
# Find the first player with the maximum value in each position
max_value_players = data.groupby('Best_Position').apply(lambda x: x.loc[x['Value(in_Euro)'].idxmax()])

# Create the grouped bar chart
plt.figure(figsize=(20, 6))
positions = max_value_players['Best_Position']
values = max_value_players['Value(in_Euro)']
players = max_value_players['Known_As']
plt.bar(positions, values, label='Players')
plt.xlabel('Position')
plt.ylabel('Value')
plt.title('First Player with Maximum Value in Each Position')
plt.xticks(rotation=45)
plt.legend()

# Annotate player names on the bars
for i, value in enumerate(values):
    plt.text(i, value, players.iloc[i], ha='center', va='bottom')

plt.tight_layout()
plt.show()
